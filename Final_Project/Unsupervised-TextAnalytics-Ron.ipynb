# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %mkdir gdrive/MyDrive/DSKU/datasets
#%cd gdrive/MyDrive/Datasets
# %cd gdrive/MyDrive/DSKU/datasets
# Out:
# /content/gdrive/MyDrive/DSKU/datasets

# %%
# load all the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings

pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore")

# %%
# focused countries

COUNTRIES = """Argentina
Bolivia
Brazil
Chile
Colombia
Costa Rica
Cuba
Dominican Republic
Ecuador
El Salvador
French Guiana
Guadeloupe
Guatemala
Haiti
Honduras
Martinique
Mexico
Nicaragua
Panama
Paraguay
Peru
Puerto Rico
Saint Barthélemy
Saint Martin
Uruguay
Venezuela
Brunei
Cambodia
Timor-Leste
Indonesia
Laos
Malaysia
Burma (Myanmar)
Philippines
Singapore
Thailand
Vietnam""".split("\n")

# %%
def readCsvFile(filepath):
    """
        Function to read csv file
        args:
            filepath : path to csv file
        return:
            df : dataframe
    """
    
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.lower().str.replace(" ", "_")
    
    df.drop(df.columns[-1], inplace=True, axis = 1)
    
    return df

# %%
# %pwd
# Out:
# '/content/gdrive/MyDrive/DSKU/datasets'

# %%
raw_us_aid = readCsvFile('us_foreign_aid_complete.csv')

# %%
raw_us_aid.head(2)
# Out:
#    country_id country_code country_name  region_id             region_name  \
# 0           4          AFG  Afghanistan          4  South and Central Asia
# 1           4          AFG  Afghanistan          4  South and Central Asia
#
#    income_group_id   income_group_name income_group_acronym  \
# 0              1.0  Low Income Country                  LIC
# 1              1.0  Low Income Country                  LIC
#
#    managing_agency_id managing_agency_acronym  \
# 0                   1                   USAID
# 1                   1                   USAID
#
#                         managing_agency_name  \
# 0  U.S. Agency for International Development
# 1  U.S. Agency for International Development
#
#    managing_sub-agency_or_bureau_id managing_sub-agency_or_bureau_acronym  \
# 0                                20                                  ASIA
# 1                                20                                  ASIA
#
#   managing_sub-agency_or_bureau_name  implementing_partner_category_id  \
# 0                    Bureau for Asia                                 1
# 1                    Bureau for Asia                                 1
#
#   implementing_partner_category_name  implementing_partner_sub-category_id  \
# 0                         Government                                     1
# 1                         Government                                     1
#
#   implementing_partner_sub-category_name  implementing_partner_id  \
# 0             Government - United States                  1000001
# 1             Government - United States                  1000001
#
#                            implementing_partner_name  \
# 0  U.S. Government - U.S. Agency for Internationa...
# 1  U.S. Government - U.S. Agency for Internationa...
#
#    international_category_id international_category_name  \
# 0                          1                   Education
# 1                          1                   Education
#
#    international_sector_code international_sector_name  \
# 0                        112           Basic Education
# 1                        112           Basic Education
#
#    international_purpose_code international_purpose_name  us_category_id  \
# 0                       11220          Primary education               4
# 1                       11220          Primary education               4
#
#                 us_category_name  us_sector_id   us_sector_name  \
# 0  Education and Social Services            20  Basic Education
# 1  Education and Social Services            20  Basic Education
#
#   funding_account_id                               funding_account_name  \
# 0            72x1021  Agency for International Development, Developm...
# 1            72x1021  Agency for International Development, Developm...
#
#    funding_agency_id                        funding_agency_name  \
# 0                  1  U.S. Agency for International Development
# 1                  1  U.S. Agency for International Development
#
#   funding_agency_acronym  foreign_assistance_objective_id  \
# 0                  USAID                                1
# 1                  USAID                                1
#
#   foreign_assistance_objective_name  aid_type_group_id   aid_type_group_name  \
# 0                          Economic                  4  Technical Assistance
# 1                          Economic                  4  Technical Assistance
#
#    aid_type_id                  aid_type_name  activity_id  submission_id  \
# 0           13  Technical Cooperation - Other       144477             76
# 1           13  Technical Cooperation - Other       144477             76
#
#                               activity_name  \
# 0  Office Of Social Sector Dev. - Education
# 1  Office Of Social Sector Dev. - Education
#
#                        activity_description activity_project_number  \
# 0  Office Of Social Sector Dev. - Education                 306-002
# 1  Office Of Social Sector Dev. - Education                 306-002
#
#   activity_budget_amount activity_start_date activity_end_date  \
# 0                    NaN                 NaN               NaN
# 1                    NaN                 NaN               NaN
#
#    transaction_type_id transaction_type_name fiscal_year transaction_date  \
# 0                    2           Obligations        2006        01MAR2006
# 1                    3         Disbursements        2006        01MAR2006
#
#    current_dollar_amount  constant_dollar_amount  submission_activity_id  \
# 0                  37760                   47793                   30831
# 1                    983                    1244                   30831
#
#    finance_type  dac_flow_id
# 0           110            1
# 1           110            1

# %%
raw_us_aid['fiscal_year'] = np.where(raw_us_aid.fiscal_year=="1976tq", "1976", raw_us_aid.fiscal_year)

# %%
raw_us_aid['fiscal_year'] = raw_us_aid['fiscal_year'].astype(int)

# %%
# consider latest government
latest_foreign_aid = raw_us_aid[(raw_us_aid.fiscal_year>=2021) & (raw_us_aid.fiscal_year<2022)]\
                  .query("country_name == @COUNTRIES")

# %%
latest_foreign_aid.groupby(['country_code']).agg({'activity_description':'nunique'}).reset_index()
# Out:
#    country_code  activity_description
# 0           ARG                   101
# 1           BOL                    32
# 2           BRA                   150
# 3           CHL                    16
# 4           COL                  1972
# 5           CRI                  1051
# 6           CUB                    18
# 7           DOM                   302
# 8           ECU                   452
# 9           GTM                  2017
# 10          HND                  1163
# 11          HTI                   539
# 12          IDN                   554
# 13          KHM                   148
# 14          LAO                   178
# 15          MEX                  1055
# 16          MMR                   182
# 17          MYS                   123
# 18          NIC                   126
# 19          PAN                   823
# 20          PER                  1200
# 21          PHL                   496
# 22          PRY                    75
# 23          SGP                     4
# 24          SLV                  1310
# 25          THA                   480
# 26          TLS                    71
# 27          URY                     7
# 28          VEN                    77
# 29          VNM                   542

# %%
latest_foreign_aid[latest_foreign_aid.duplicated(['country_code', 'activity_description'])].head()
# Out:
#         country_id country_code country_name  region_id         region_name  \
# 107781          32          ARG    Argentina          6  Western Hemisphere
# 107783          32          ARG    Argentina          6  Western Hemisphere
# 107784          32          ARG    Argentina          6  Western Hemisphere
# 107785          32          ARG    Argentina          6  Western Hemisphere
# 107787          32          ARG    Argentina          6  Western Hemisphere
#
#         income_group_id            income_group_name income_group_acronym  \
# 107781              3.0  Upper Middle Income Country                 UMIC
# 107783              3.0  Upper Middle Income Country                 UMIC
# 107784              3.0  Upper Middle Income Country                 UMIC
# 107785              3.0  Upper Middle Income Country                 UMIC
# 107787              3.0  Upper Middle Income Country                 UMIC
#
#         managing_agency_id managing_agency_acronym managing_agency_name  \
# 107781                   2                   STATE  Department of State
# 107783                   2                   STATE  Department of State
# 107784                   2                   STATE  Department of State
# 107785                   2                   STATE  Department of State
# 107787                   2                   STATE  Department of State
#
#         managing_sub-agency_or_bureau_id  \
# 107781                                62
# 107783                                62
# 107784                                62
# 107785                                62
# 107787                                62
#
#        managing_sub-agency_or_bureau_acronym  \
# 107781                                   INL
# 107783                                   INL
# 107784                                   INL
# 107785                                   INL
# 107787                                   INL
#
#                        managing_sub-agency_or_bureau_name  \
# 107781  International Narcotics and Law Enforcement Af...
# 107783  International Narcotics and Law Enforcement Af...
# 107784  International Narcotics and Law Enforcement Af...
# 107785  International Narcotics and Law Enforcement Af...
# 107787  International Narcotics and Law Enforcement Af...
#
#         implementing_partner_category_id implementing_partner_category_name  \
# 107781                                 7                       Multilateral
# 107783                                 8                        Enterprises
# 107784                                 8                        Enterprises
# 107785                                 8                        Enterprises
# 107787                                 8                        Enterprises
#
#         implementing_partner_sub-category_id  \
# 107781                                    12
# 107783                                    19
# 107784                                    19
# 107785                                    19
# 107787                                    19
#
#        implementing_partner_sub-category_name  implementing_partner_id  \
# 107781          Multilateral - United Nations                  4000455
# 107783            Enterprises - United States                  3990008
# 107784            Enterprises - United States                  3990008
# 107785            Enterprises - United States                  3990008
# 107787            Enterprises - United States                  3990208
#
#                        implementing_partner_name  international_category_id  \
# 107781  United Nations Office on Drugs and Crime                          3
# 107783          Enterprise - United States Other                         10
# 107784          Enterprise - United States Other                         10
# 107785          Enterprise - United States Other                         10
# 107787       Enterprise - United States Redacted                          3
#
#        international_category_name  international_sector_code  \
# 107781                  Governance                        151
# 107783        Administrative Costs                        911
# 107784        Administrative Costs                        911
# 107785        Administrative Costs                        911
# 107787                  Governance                        151
#
#            international_sector_name  international_purpose_code  \
# 107781  Government and Civil Society                       15130
# 107783            Operating Expenses                       91010
# 107784            Operating Expenses                       91010
# 107785            Operating Expenses                       91010
# 107787  Government and Civil Society                       15130
#
#             international_purpose_name  us_category_id  \
# 107781  Legal and judicial development               2
# 107783              Operating Expenses               8
# 107784              Operating Expenses               8
# 107785              Operating Expenses               8
# 107787  Legal and judicial development               2
#
#                                us_category_name  us_sector_id  \
# 107781  Democracy, Human Rights, and Governance             7
# 107783                          Program Support            41
# 107784                          Program Support            41
# 107785                          Program Support            41
# 107787  Democracy, Human Rights, and Governance             7
#
#                       us_sector_name funding_account_id  \
# 107781  Rule of Law and Human Rights            11x1022
# 107783   Direct Administrative Costs            11x1022
# 107784   Direct Administrative Costs            11x1022
# 107785   Direct Administrative Costs            11x1022
# 107787  Rule of Law and Human Rights            11x1022
#
#                                      funding_account_name  funding_agency_id  \
# 107781  International Narcotics Control and Law Enforc...                  2
# 107783  International Narcotics Control and Law Enforc...                  2
# 107784  International Narcotics Control and Law Enforc...                  2
# 107785  International Narcotics Control and Law Enforc...                  2
# 107787  International Narcotics Control and Law Enforc...                  2
#
#         funding_agency_name funding_agency_acronym  \
# 107781  Department of State                  STATE
# 107783  Department of State                  STATE
# 107784  Department of State                  STATE
# 107785  Department of State                  STATE
# 107787  Department of State                  STATE
#
#         foreign_assistance_objective_id foreign_assistance_objective_name  \
# 107781                                1                          Economic
# 107783                                1                          Economic
# 107784                                1                          Economic
# 107785                                1                          Economic
# 107787                                1                          Economic
#
#         aid_type_group_id   aid_type_group_name  aid_type_id  \
# 107781                  3          Project-Type            8
# 107783                  6  Administrative Costs           17
# 107784                  6  Administrative Costs           17
# 107785                  6  Administrative Costs           17
# 107787                  3          Project-Type            8
#
#                                             aid_type_name  activity_id  \
# 107781  Project-type interventions - not Investment Re...       345875
# 107783        Administrative costs not included elsewhere       312736
# 107784        Administrative costs not included elsewhere       312739
# 107785        Administrative costs not included elsewhere       312740
# 107787  Project-type interventions - not Investment Re...       305980
#
#         submission_id                                      activity_name  \
# 107781            105  Bureau of International Narcotics and Law Enfo...
# 107783            105  Bureau of International Narcotics and Law Enfo...
# 107784            105  Bureau of International Narcotics and Law Enfo...
# 107785            105  Bureau of International Narcotics and Law Enfo...
# 107787            105  Bureau of International Narcotics and Law Enfo...
#
#                                      activity_description  \
# 107781  U.S. Department of State: Bureau of Internatio...
# 107783  U.S. Department of State: Bureau of Internatio...
# 107784  U.S. Department of State: Bureau of Internatio...
# 107785  U.S. Department of State: Bureau of Internatio...
# 107787  U.S. Department of State: Bureau of Internatio...
#
#        activity_project_number activity_budget_amount activity_start_date  \
# 107781          SINLEC21LA3353                    NaN                 NaN
# 107783             20730110299                    NaN                 NaN
# 107784             20730110299                    NaN                 NaN
# 107785             20730110299                    NaN                 NaN
# 107787               PR9694052                    NaN                 NaN
#
#        activity_end_date  transaction_type_id transaction_type_name  \
# 107781        2021-09-30                    3         Disbursements
# 107783        2020-12-02                    2           Obligations
# 107784        2021-05-04                    2           Obligations
# 107785        2021-08-20                    2           Obligations
# 107787        2021-02-18                    2           Obligations
#
#         fiscal_year transaction_date  current_dollar_amount  \
# 107781         2021        30SEP2021                 600000
# 107783         2021        02DEC2020                  13440
# 107784         2021        04MAY2021                   -900
# 107785         2021        20AUG2021                   1613
# 107787         2021        18FEB2021                    820
#
#         constant_dollar_amount  submission_activity_id  finance_type  \
# 107781                  589998                  134457           110
# 107783                   13216                  101318           110
# 107784                    -885                  101321           110
# 107785                    1587                  101322           110
# 107787                     806                   94562           110
#
#         dac_flow_id
# 107781            1
# 107783            1
# 107784            1
# 107785            1
# 107787            1

# %%
latest_foreign_aid['region_name'].value_counts()
# Out:
# Western Hemisphere       53778
# East Asia and Oceania    17930
# Name: region_name, dtype: int64

# %% [markdown]
# # Text analytics
# ## Clustering activity description using topic modelling
# ## Approach 2: contextulized topic modeling

# %%
# %%capture
# !pip install contextualized_topic_models
# !pip install sentence-transformers

# %%
from contextualized_topic_models.models.ctm import ZeroShotTM, CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessingStopwords
import nltk
import torch
import random
import numpy as np

# %%
def fix_seeds():
  torch.manual_seed(10)
  torch.cuda.manual_seed(10)
  np.random.seed(10)
  random.seed(10)
  torch.backends.cudnn.enabled = False
  torch.backends.cudnn.deterministic = True

# %%
from nltk.corpus import stopwords as stop_words
nltk.download('stopwords')
stopwords = list(set(stop_words.words('english')))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
latest_foreign_aid['activity_description'] = latest_foreign_aid['activity_description'].astype(str)

# %%
activity_df = latest_foreign_aid.groupby("country_code")['activity_description'].apply(' '.join).reset_index()

# %%
activity_df.head()
# Out:
#   country_code                               activity_description
# 0          ARG  U.S. Department of State: Bureau of Democracy,...
# 1          BOL  USAID redacted this field in accordance with t...
# 2          BRA  USAID redacted this field in accordance with t...
# 3          CHL  Natural Hazard Mitigation Global Technical Ass...
# 4          COL  USAID redacted this field in accordance with t...

# %%
activity_df.shape
# Out:
# (30, 2)

# %%
activity_df.activity_description.apply(lambda x:len(x))
# Out:
# 0      216460
# 1       36221
# 2      364251
# 3       35149
# 4     2473130
# 5     1250301
# 6       53761
# 7      639143
# 8      832511
# 9     2493855
# 10    1787331
# 11     789080
# 12    1114818
# 13     607652
# 14     320472
# 15    1752786
# 16     357422
# 17     123541
# 18     199043
# 19     918896
# 20    1531719
# 21     984048
# 22     423214
# 23       1077
# 24    1522151
# 25     589827
# 26     181767
# 27      10148
# 28     184925
# 29     888647
# Name: activity_description, dtype: int64

# %%
# get text
activities = activity_df['activity_description'].tolist()

# %%
uniq_activities = set(activities)

# %%
documents = list(uniq_activities)

# %%
len(documents)
# Out:
# 30

# %%
documents[1]
# Out:
# "Health: PAHO Umbrella Grant 2016-2021 Housed in a 19th-century villa, the Blanes Municipal Museum displays Uruguayan art from the nation's founding in the 19th century to the present day. This project includes the conservation of the building's masonry facades. Housed in a 19th-century villa, the Blanes Municipal Museum displays Uruguayan art from the nation's founding in the 19th century to the present day. This project includes the conservation of the building's masonry facades. The eastern seaboard of Uruguay includes a chain of 5 coastal lagoons, supporting globally important populations of migratory shorebirds that use the surrounding grasslands, wetlands and sandy areas, as well as the lagoon shores, as wintering areas. This region, covering 2,471,000 acres, is under pressure by threats such as agriculture, intensive livestock ranching, urbanization and recreational activities such as uncontrolled tourism. Partners will secure long-term shorebird conservation by developing and empowering an integrative collaborative local conservation network with landowners and other key stakeholders taking direct action on habitat conservation and restoration. Acting jointly with key stakeholders of the region, the management of the 5 lagoons will be integrated by creating local and regional working groups to subscribe local and cross-site management and conservation agreements. Primary actions will include the application of Best Management Practices in 98,800 acres, habitat restoration in 490 acres, Western Hemisphere Shorebird Reserve Network site designations, shorebird population estimates, the building of high-resolution distribution maps, as well as the development of a citizen scientist group that safeguards habitat integrity for neotropical migrant shorebirds. Finally, partners will put together all the experience, contacts, and information to develop a regional plan for shorebird conservation for the lagoon belt. The eastern seaboard of Uruguay includes a chain of 5 coastal lagoons, supporting globally important populations of migratory shorebirds that use the surrounding grasslands, wetlands and sandy areas, as well as the lagoon shores, as wintering areas. This region, covering 2,471,000 acres, is under pressure by threats such as agriculture, intensive livestock ranching, urbanization and recreational activities such as uncontrolled tourism. Partners will secure long-term shorebird conservation by developing and empowering an integrative collaborative local conservation network with landowners and other key stakeholders taking direct action on habitat conservation and restoration. Acting jointly with key stakeholders of the region, the management of the 5 lagoons will be integrated by creating local and regional working groups to subscribe local and cross-site management and conservation agreements. Primary actions will include the application of Best Management Practices in 98,800 acres, habitat restoration in 490 acres, Western Hemisphere Shorebird Reserve Network site designations, shorebird population estimates, the building of high-resolution distribution maps, as well as the development of a citizen scientist group that safeguards habitat integrity for neotropical migrant shorebirds. Finally, partners will put together all the experience, contacts, and information to develop a regional plan for shorebird conservation for the lagoon belt. The eastern seaboard of Uruguay includes a chain of 5 coastal lagoons, supporting globally important populations of migratory shorebirds that use the surrounding grasslands, wetlands and sandy areas, as well as the lagoon shores, as wintering areas. This region, covering 2,471,000 acres, is under pressure by threats such as agriculture, intensive livestock ranching, urbanization and recreational activities such as uncontrolled tourism. Partners will secure long-term shorebird conservation by developing and empowering an integrative collaborative local conservation network with lando ...

# %%
documents[0]
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sp = WhiteSpacePreprocessingStopwords(documents, stopwords_list=stopwords)

# %%
preprocessed_documents, unpreprocessed_corpus, vocab, _ = sp.preprocess()

# %%
tp = TopicModelDataPreparation("paraphrase-distilroberta-base-v2")

# %%
training_dataset = tp.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)
# Out:
# Downloading (…)2b9e5/.gitattributes:   0%|          | 0.00/736 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)3c1ed2b9e5/README.md:   0%|          | 0.00/3.74k [00:00<?, ?B/s]
# Downloading (…)1ed2b9e5/config.json:   0%|          | 0.00/686 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading (…)c1ed2b9e5/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)2b9e5/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading (…)c1ed2b9e5/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)ed2b9e5/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from contextualized_topic_models.evaluation.measures import CoherenceNPMI, InvertedRBO
corpus = [d.split() for d in preprocessed_documents]

num_topics = [5, 10, 15, 20]
num_runs = 5

best_topic_coherence = -999
best_num_topics = 0
for n_components in num_topics:
  for i in range(num_runs):
    print("num topics:", n_components, "/ num run:", i)
    ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, 
                     n_components=n_components, num_epochs=50)
    ctm.fit(training_dataset) # run the model
    coh = CoherenceNPMI(ctm.get_topic_lists(10), corpus)
    coh_score = coh.score()
    print("coherence score:", coh_score)
    if best_topic_coherence < coh_score:
      best_topic_coherence = coh_score
      best_num_topics = n_components
    print("current best coherence", best_topic_coherence, "/ best num topics", best_num_topics)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# num topics: 5 / num run: 0
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-36-9044726cdfe3> in <cell line: 9>()
#      12     ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768,
#      13                      n_components=n_components, num_epochs=50)
# ---> 14     ctm.fit(training_dataset) # run the model
#      15     coh = CoherenceNPMI(ctm.get_topic_lists(10), corpus)
#      16     coh_score = coh.score()
#
# /usr/local/lib/python3.10/dist-packages/contextualized_topic_models/models/ctm.py in fit(self, train_dataset, validation_dataset, save_dir, verbose, patience, delta, n_samples, do_train_predictions)
#     353             # train epoch
#     354             s = datetime.datetime.now()
# --> 355             sp, train_loss = self._train_epoch(train_loader)
#     356             samples_processed += sp
#     357             e = datetime.datetime.now()
#
# /usr/local/lib/python3.10/dist-packages/contextualized_topic_models/models/ctm.py in _train_epoch(self, loader)
#     270             train_loss += loss.item()
#     271
# --> 272         train_loss /= samples_processed
#     273
#     274         return samples_processed, train_loss
#
# ZeroDivisionError: division by zero

# %%
fix_seeds() # uncomment if you don't want to fix the random seeds

num_topics = 5
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, n_components=num_topics, num_epochs=50)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ctm.fit(training_dataset) # run the model
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-39-3c53a8820d9b> in <cell line: 1>()
# ----> 1 ctm.fit(training_dataset) # run the model
#
# /usr/local/lib/python3.10/dist-packages/contextualized_topic_models/models/ctm.py in fit(self, train_dataset, validation_dataset, save_dir, verbose, patience, delta, n_samples, do_train_predictions)
#     353             # train epoch
#     354             s = datetime.datetime.now()
# --> 355             sp, train_loss = self._train_epoch(train_loader)
#     356             samples_processed += sp
#     357             e = datetime.datetime.now()
#
# /usr/local/lib/python3.10/dist-packages/contextualized_topic_models/models/ctm.py in _train_epoch(self, loader)
#     270             train_loss += loss.item()
#     271
# --> 272         train_loss /= samples_processed
#     273
#     274         return samples_processed, train_loss
#
# ZeroDivisionError: division by zero

# %%
ctm.get_topic_lists(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-d1f8363cb540> in <cell line: 1>()
# ----> 1 ctm.get_topic_lists(5)
#
# /usr/local/lib/python3.10/dist-packages/contextualized_topic_models/models/ctm.py in get_topic_lists(self, k)
#     611         topics = []
#     612         for i in range(self.n_components):
# --> 613             _, idxs = torch.topk(component_dists[i], k)
#     614             component_words = [self.idx2token[idx] for idx in idxs.cpu().numpy()]
#     615             topics.append(component_words)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
topics_predictions = ctm.training_doc_topic_distributions # get all the topic predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
np.sum(topics_predictions[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-f56bdc9420fa> in <cell line: 1>()
# ----> 1 np.sum(topics_predictions[1])
#
# TypeError: 'NoneType' object is not subscriptable
# 0it [00:11, ?it/s]

# %%
np.sum(topics_predictions, axis=1)

# %%
len(topics_predictions)

# %%
len(training_dataset)

# %% [markdown]
# # Topic clustering

# %%
proba_dist = pd.read_pickle("results/proba_dist_topic_modelling.pkl")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-b123976a3b26> in <cell line: 1>()
# ----> 1 proba_dist = pd.read_pickle("results/proba_dist_topic_modelling.pkl")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     188     """
#     189     excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 190     with get_handle(
#     191         filepath_or_buffer,
#     192         "rb",
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/proba_dist_topic_modelling.pkl'

# %%
proba_dist.head(2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-ab7eac5c052d> in <cell line: 1>()
# ----> 1 proba_dist.head(2)
#
# NameError: name 'proba_dist' is not defined

# %%
# # create dataframe from topic distribution
# proba_dist = pd.DataFrame(topics_predictions)
# proba_dist['country_code'] = activity_df['country_code']

# %%
# %pwd

# %%
# proba_dist.to_pickle("results/proba_dist_topic_modelling.pkl")

# %%
activity_df.head(2)

# %%
latest_foreign_aid.head(2)

# %%
latest_foreign_aid['managing_agency_name'].unique()

# %%
latest_foreign_aid.groupby(['country_code', 'managing_agency_name',
                            'transaction_type_name']).agg({'constant_dollar_amount':'sum'}).reset_index()

# %% [markdown]
# ## KMeans

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from yellowbrick.cluster import silhouette_visualizer, SilhouetteVisualizer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/yellowbrick/style/colors.py:35: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   mpl_ge_150 = LooseVersion(mpl.__version__) >= "1.5.0"
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /usr/local/lib/python3.10/dist-packages/yellowbrick/style/rcmod.py:31: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   mpl_ge_150 = LooseVersion(mpl.__version__) >= "1.5.0"
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
# filter for only focused countries
proba_dist = proba_dist[proba_dist.country_code.isin(latest_foreign_aid.country_code)]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-86886051b68d> in <cell line: 2>()
#       1 # filter for only focused countries
# ----> 2 proba_dist = proba_dist[proba_dist.country_code.isin(latest_foreign_aid.country_code)]
#
# NameError: name 'proba_dist' is not defined

# %%
# split data
X = proba_dist.iloc[:,0:-1]

# %%
X.head(2)

# %%
# fill na (since value not available, no Aid was provided for that country that year)
X.fillna(value=0, inplace=True)

# %%
scaler = StandardScaler()

# %%
scaled_x = scaler.fit_transform(X)

# %%
silhouette_visualizer(KMeans(10, random_state=42), X, colors='yellowbrick')

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "random_state": 42
}

# %%
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

plt.figure(figsize=(6, 4))
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.title("SSE for KMeans cluster range")

# %%
n = 3

# %%
country_3_clusters = KMeans(n_clusters=n, random_state=42)

# %%
proba_dist['kmeans_3'] = country_3_clusters.fit_predict(X)

# %%
centers = country_3_clusters.cluster_centers_

# %%
plt.figure(figsize=(10, 5))
plt.scatter(scaled_x[:, 0], scaled_x[:, 1],
            c=proba_dist['kmeans_3'], s=50, cmap='viridis')

# %%
proba_dist.groupby('kmeans_3').agg({'country_code':['unique', 'nunique']}).reset_index()

# %%
print("# of Countries in cluster distribution")
proba_dist['kmeans_3'].value_counts()

# %%
# mapping dictionary
country_mapping = dict(zip(latest_foreign_aid.country_code, latest_foreign_aid.country_name))

# %%
proba_dist['country_name'] = proba_dist['country_code'].map(country_mapping)

# %%
proba_dist['region'] = np.where(proba_dist.country_name.isin(COUNTRIES[26:-1]), "South East Asia", "Latin America")

# %%
proba_dist.groupby(['kmeans_3', 'country_name']).agg({'country_code':"unique", "region":'unique'}).reset_index()

# %% [markdown]
# # Sentence Transformers
# ## Another approach

# %%
# %%capture
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer,util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
len(documents)

# %%
#Encode all sentences
embeddings = model.encode(documents, normalize_embeddings=True)

# %%
#Compute cosine similarity between all pairs
cos_sim = util.cos_sim(embeddings, embeddings)

# %%
cos_sim[:3]

# %%
#Add all pairs to a list with their cosine similarity score
all_sentence_combinations = []
for i in range(len(cos_sim)-1):
    for j in range(i+1, len(cos_sim)):
        all_sentence_combinations.append((cos_sim[i][j], i, j))
# all_sentence_combinations

# %%
#Sort list by the highest cosine similarity score
all_sentence_combinations = sorted(all_sentence_combinations, key=lambda x: x[0], reverse=True)

print("Top-2 most similar pairs:")
for score, i, j in all_sentence_combinations[0:2]:
    print("{} \t {} \t {:.4f}".format(documents[i], documents[j], cos_sim[i][j]))

# %%
embedder = SentenceTransformer('all-mpnet-base-v2')

# %%
corpus_embeddings = embedder.encode(documents)

# %%
len(corpus_embeddings[0])

# %%
# Normalize the embeddings to unit length
# corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# %%
len(corpus_embeddings)

# %%
X = scaler.fit_transform(corpus_embeddings)

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "random_state": 42
}

# %%
sse = []
for k in range(1, 15):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

plt.figure(figsize=(6, 4))
plt.plot(range(1, 15), sse)
plt.xticks(range(1, 15))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.title("SSE for KMeans cluster range")

# %%
silhouette_visualizer(KMeans(10, random_state=42), corpus_embeddings, colors='yellowbrick')

# %%
clustering_model = KMeans(n_clusters=4)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_
print(cluster_assignment)

# %%
proba_dist['kmeans_word_embdd'] = cluster_assignment

# %%
proba_dist.groupby(['kmeans_word_embdd']).agg({'country_code':"unique", "region":'unique'}).reset_index()

# %%
centers = clustering_model.cluster_centers_

# %%
corpus_embeddings[:,0]

# %%
plt.figure(figsize=(10, 5))
plt.scatter(corpus_embeddings[:, 2], corpus_embeddings[:, 3],
            c=proba_dist['kmeans_word_embdd'], s=50, cmap='viridis')

# %% [markdown]
# ## DBSCAN clustering
# ### clustering using word embeddings (density based clustering)
